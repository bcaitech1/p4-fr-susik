# %%
# !pip install -r requirements_default.txt

# %%
# !python train.py
# Out:
# --------------------------------
# Running SATRN on device cuda
#
# [+] System environments
#  The number of gpus : 1
#  The number of cpus : 8
#  Memory Size : 87G
#
# [+] Data
#  The number of train samples : 90000
#  The number of validation samples : 10000
#  The number of classes : 245
#
# [+] Network
#  Type: SATRN
#  Encoder parameters: 5875140
#  Decoder parameters: 988917
#
# ----------GT (train)
# <SOS> v < 0 <EOS>
# <SOS> \left( + \right) \times \left( + \right) = \left( + \right) <EOS>
# <SOS> = 8 \sqrt { 3 } + 6 \sqrt { 3 } = 1 4 \sqrt { 3 } \left( c m ^ { 2 } \right) <EOS>
# ----------PR (train)
# a { 0 <EOS> <EOS> <EOS> } 0 } <EOS> <EOS> 0 <EOS> 0 0 <EOS> 0 <EOS> } 0 <EOS> 0 <EOS> 0 <EOS> } 0 0 <EOS> <EOS> <EOS> 0 } } <EOS> <EOS> } <EOS> 0 0 <EOS> <EOS> 0 <EOS> 0 <EOS> 0 } } } <EOS> <EOS> 0 <EOS> 0 0 <EOS> 0 } <EOS> <EOS> } 0 <EOS> <EOS> <EOS> 0
# ...

# %%
# !ls
# Out:
# EDA.ipynb	data_tools    metrics.py		submit
# README.md	dataset.py    networks			train.ipynb
# Untitled.ipynb	download.sh   requirements.txt		train.py
# __pycache__	flags.py      requirements_default.txt	train2.ipynb
# checkpoint.py	inference.py  scheduler.py		utils.py
# configs		log	      submission.txt

# %%
# !python inference.py
# Out:
# --------------------------------
# Running SATRN on device cuda
#
# [+] Checkpoint
#  Resuming from epoch : 7
#
# 62
# [+] Data
#  The number of test samples : 32
#
# 100%|█████████████████████████████████████████████| 4/4 [00:08<00:00,  2.23s/it]
