# %%
# !python train.py
# Out:
# --------------------------------
# Running SATRN on device cuda
#
# [+] System environments
#  The number of gpus : 1
#  The number of cpus : 8
#  Memory Size : 86G
#
# [+] Data
#  The number of train samples : 80000
#  The number of validation samples : 20000
#  The number of classes : 245
#
# [+] Network
#  Type: SATRN
#  Encoder parameters: 5875140
#  Decoder parameters: 988917
#
# ----------GT (train)
# <SOS> \exists \frac { 1 } { 1 0 ^ { N } } < \epsilon <EOS>
# <SOS> f \left( 1 0 \right) = 4 <EOS>
# <SOS> \left( x + 3 y - 2 \right) \left( x - 2 y + 3 \right) <EOS>
# ----------PR (train)
# \frac \frac { 1 } { 1 } } { 2 } } { 1 } <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# x \left( x \right) \right) <EOS> 2 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# ...

# %%
# !ls
# Out:
# EDA.ipynb      configs	    flags.py	  networks	    submit
# README.md      data_tools   inference.py  requirements.txt  train.ipynb
# __pycache__    dataset.py   log		  scheduler.py	    train.py
# checkpoint.py  download.sh  metrics.py	  submission.txt    utils.py

# %%
# !python inference.py
# Out:
# --------------------------------
# Running SATRN on device cuda
#
# [+] Checkpoint
#  Resuming from epoch : 50
#
# 128
# [+] Data
#  The number of test samples : 32
#
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.34s/it]
